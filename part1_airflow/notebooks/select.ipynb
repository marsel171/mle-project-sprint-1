# %%
from sqlalchemy import create_engine
import os
import numpy as np
import pandas as pd
from dotenv import load_dotenv

def create_connection():

    load_dotenv()
    host = os.environ.get('DB_DESTINATION_HOST')
    port = os.environ.get('DB_DESTINATION_PORT')
    db = os.environ.get('DB_DESTINATION_NAME')
    username = os.environ.get('DB_DESTINATION_USER')
    password = os.environ.get('DB_DESTINATION_PASSWORD')
    
    print(f'postgresql://{username}:{password}@{host}:{port}/{db}')
    conn = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{db}')
    return conn

# установите соединение с базой
conn = create_connection()

data = pd.read_sql('select * from buildings', conn)
# Out:
# postgresql://mle_20240919_f8666628fb:b4759a54ffe6447e81eaef1c5d36fff1@rc1b-uh7kdmcx67eomesf.mdb.yandexcloud.net:6432/playground_mle_20240919_f8666628fb

# %%
data
# Out:
#           id  build_year  building_type_int   latitude  longitude  \
# 0       6220        1965                  6  55.717113  37.781120
# 1      18012        2001                  2  55.794849  37.608013
# 2      17821        2000                  4  55.740040  37.761742
# 3      18579        2002                  4  55.672016  37.570877
# 4       9293        1971                  1  55.808807  37.707306
# ...      ...         ...                ...        ...        ...
# 24615  22074        2012                  2  55.737213  37.493084
# 24616  14084        1984                  4  55.626541  37.720547
# 24617  13923        1983                  4  55.798008  37.801689
# 24618  18289        2001                  4  55.884998  37.535870
# 24619   3162        1960                  1  55.727470  37.768677
#
#        ceiling_height  flats_count  floors_total  has_elevator
# 0                2.64           84            12          True
# 1                3.00           97            10          True
# 2                2.70           80            10          True
# 3                2.64          771            17          True
# 4                2.60          208             9          True
# ...               ...          ...           ...           ...
# 24615            3.00          132            22          True
# 24616            2.64          361            16          True
# 24617            2.64          270            17          True
# 24618            2.65          118            17          True
# 24619            2.48           80             5         False
#
# [24620 rows x 9 columns]
